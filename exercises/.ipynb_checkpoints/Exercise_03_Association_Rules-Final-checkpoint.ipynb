# %%
with open('store_data.csv') as f:
    records = []
    for line in f:
        records.append(line.strip().split(','))

# %%
inst_all= []
for el in records:
    for x in el:
        inst_all.append(x)
#print(inst_all)

# %% [markdown]
# # Try3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules


#dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

dataset=  records

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
print(df.shape)
df.head(3)
# Out:
# (7501, 120)
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False              True              False
# 1        False       False             False              False
# 2        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# ...

# %%
support_of_all=df.sum(axis = 0, skipna = True) 
support_of_all=support_of_all/len(df)

# %%
sns.swarmplot(y=support_of_all)

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (milk, mineral water, ground beef)
# 253  0.017064  (spaghetti, mineral water, ground beef)
# 254  0.015731         (milk, spaghetti, mineral water)
# 255  0.010265    (olive oil, spaghetti, mineral water)
# 256  0.011465     (pancakes, spaghetti, mineral water)
#
# [257 rows x 2 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# %%
7501*0.01
# Out:
# 75.01

# %%
from ipywidgets import *
dfx =[]
def func(f):
    global dfx
    dfx=association_rules(frequent_itemsets, metric="lift", min_threshold=f)
    display(dfx)
interact(func,f=FloatSlider(1.1,min=1, max=3, step=0.1,continuous_update=False));
# Out:
# interactive(children=(FloatSlider(value=1.1, continuous_update=False, description='f', max=3.0, min=1.0), Outp…

# %%
#dfx[dfx['antecedents'].apply(lambda x: len(x)) == 2 ] #access only values, where antecends have two entries
dfx.iloc[[index for  index,  setx in enumerate(dfx['antecedents']) if 'spaghetti' in setx]] # antecends must contain spagetti
# Out:
#                         antecedents                         consequents  \
# 23                      (spaghetti)                           (burgers)
# 41                      (spaghetti)                              (cake)
# 56                      (spaghetti)                           (chicken)
# 91                      (spaghetti)                         (chocolate)
# 107                     (spaghetti)                       (cooking oil)
# 127                     (spaghetti)                              (eggs)
# 151                     (spaghetti)                   (frozen smoothie)
# 169                     (spaghetti)                 (frozen vegetables)
# 176                     (spaghetti)                     (grated cheese)
# 185                     (spaghetti)                         (green tea)
# 202                     (spaghetti)                       (ground beef)
# 209                     (spaghetti)                     (herb & pepper)
# ...

# %%
dfx[dfx['support'].isin([0.017064])]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
dfx[dfx['antecedents'].isin({"spaghetti"})]

# %%
dfx=association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
# Out:
#                        antecedents      consequents  antecedent support  \
# 0                    (ground beef)  (mineral water)            0.098254
# 1                      (olive oil)  (mineral water)            0.065858
# 2                         (salmon)  (mineral water)            0.042528
# 3                           (soup)  (mineral water)            0.050527
# 4                (eggs, chocolate)  (mineral water)            0.033196
# 5         (chocolate, ground beef)  (mineral water)            0.023064
# 6                (chocolate, milk)  (mineral water)            0.032129
# 7           (spaghetti, chocolate)  (mineral water)            0.039195
# 8              (eggs, ground beef)  (mineral water)            0.019997
# 9                     (eggs, milk)  (mineral water)            0.030796
# 10       (milk, frozen vegetables)  (mineral water)            0.023597
# 11  (spaghetti, frozen vegetables)  (mineral water)            0.027863
# ...

# %%
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
# Out:
#       support                                 itemsets  it_len
# 0    0.020397                                (almonds)       1
# 1    0.033329                                (avocado)       1
# 2    0.010799                         (barbecue sauce)       1
# 3    0.014265                              (black tea)       1
# 4    0.011465                             (body spray)       1
# ..        ...                                      ...     ...
# 252  0.011065       (milk, mineral water, ground beef)       3
# 253  0.017064  (spaghetti, mineral water, ground beef)       3
# 254  0.015731         (milk, spaghetti, mineral water)       3
# 255  0.010265    (olive oil, spaghetti, mineral water)       3
# 256  0.011465     (pancakes, spaghetti, mineral water)       3
#
# [257 rows x 3 columns]
