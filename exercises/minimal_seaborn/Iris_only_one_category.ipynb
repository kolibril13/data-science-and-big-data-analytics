# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import copy
plt.figure(figsize = (16,9))
plt.rcParams['figure.dpi'] = 150
data = sns.load_dataset("iris")

# %%
data2=  data[data["species"] == "setosa"]

# %%
sns.distplot(data2["petal_length"])

# %%
sns.swarmplot(y= data["sepal_length"])

# %%
sns.violinplot(y= data["sepal_length"])
sns.swarmplot(y= data[("sepal_length")], color = "y", alpha= .3)

# %%
data2
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
sns.scatterplot(data2.index,data2["petal_length"])
sns.scatterplot(data2.index,data2["petal_width"])
sns.scatterplot(data2.index,data2["sepal_length"])
sns.scatterplot(data2.index,data2["sepal_width"])

# %%
sns.scatterplot(data=data2[["petal_length","petal_width"]])

# %%
#sns.lineplot(data=data2)
data3=data2.drop("species",axis=1)
sns.scatterplot(data=data3[["sepal_length", "petal_length"]])

# %%
g=sns.jointplot(x=data3["sepal_length"] , y =data3["petal_length"], kind="hex", color="#4CB391")

# %%
plt.hexbin(x=data3.sepal_length , y= data3.sepal_width, gridsize=10)

# %%
sns.pairplot(data=data3)
